# %%
import json
from syscopilot.system_graph import SystemGraph

print(json.dumps(SystemGraph.model_json_schema()))
# Out:
# {"$defs": {"Edge": {"properties": {"from_node": {"description": "Source node id", "title": "From Node", "type": "string"}, "to_node": {"description": "Target node id", "title": "To Node", "type": "string"}, "relation": {"enum": ["calls", "publishes", "delivers", "writes", "reads", "emits", "ingests", "triggers"], "title": "Relation", "type": "string"}, "payload": {"anyOf": [{"$ref": "#/$defs/Payload"}, {"type": "null"}], "default": null}}, "required": ["from_node", "to_node", "relation"], "title": "Edge", "type": "object"}, "Node": {"properties": {"id": {"description": "Unique identifier in the graph", "title": "Id", "type": "string"}, "kind": {"enum": ["service", "datastore", "queue", "job", "external", "client"], "title": "Kind", "type": "string"}, "name": {"title": "Name", "type": "string"}, "tech": {"anyOf": [{"type": "string"}, {"type": "null"}], "default": null, "title": "Tech"}, "compute_model": {"anyOf": [{"enum": ["request_response", "stream", "batch", "async_worker"], "type
# ...
